# %% [markdown]
# ## SERIES
#
# Las series pueden ser diccionarios.ndarrays

# %%
import numpy as np
import pandas as pd #Para importar pandas

# %%
#Seties en ndarray , necesito la cantidad necesaria

s=pd.Series(np.random.randn(5), index=["a","b"])

#s = serie

# %%
#Series en diccionarios
#pasar un diccionario
#tu misma puedes decidir el orden de los indices
#se le puede poner indice o no


d={"b":1,"a":0,"c":2} #Llaves son indices de los diccionarios
s1=pd.Series(d,index=["b","c","d","a"])

# %%
#Series en escalar

# %% [markdown]
# Se pueden hacer operaciones y cambiar las posiciones. Como se distribuyen los valores en la celda.
#
# Tambien puede devolver TRUE o FALSE, osea hacer un filtro para que solo muestre lo verdadero( Pasar los resultados T,T,F,F..... y solo retorna los true)

# %%
s=[s>s , median()]
#Saca la mediana de la serie

s= ...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s=[s>s , median()]
#       2 #Saca la mediana de la serie
#       4 s= ...
#
# NameError: name 's' is not defined

# %% [markdown]
# ## Operaciones
#
# **s[1:] + s[:-1]**
#
# Sumar cada uno de las series con la otra, componente a componente . Pero solo opera lo que está en el indice, sino sale NONE.
#
# *Los metodos solo se aplican en las ndarrays.*
#
# --> Para borrar los nones --> APLICAR EL METODO **dropna()**, a la serie
#
# **l = s[1: + s[:-1]]**
#
# **o = l.dropna()** --> Lo devuelve, solo muestra los que no tienen none

# %% [markdown]
# ## Herramientas IO (Texto ,CSV,json,...)
#
# **ARCHIVOS  MMSE**
#
# 1. Cargar librerias . os, glob
# 2. Buscar los archivos del mismo tipo --> Los va a ver como una lista

# %%
import os
import glob

# %%
current = os.getcwd() 
                    
                    # Mirar cual es la ruta actual

# %%
current
# Out:
# 'c:\\Users\\lucia\\OneDrive - Universidad de Antioquia\\4° Semestre\\info 2'

# %%
file = glob.glob(current+'/*.csv') # Te muestra solo las que tiebes de csv

# %%
file
# Out:
# ['c:\\Users\\lucia\\OneDrive - Universidad de Antioquia\\4° Semestre\\info 2\\alzheimer.csv',
#  'c:\\Users\\lucia\\OneDrive - Universidad de Antioquia\\4° Semestre\\info 2\\MMSE.csv']

# %%
alzheimer = pd.read_csv(file[0]) # Mirar como esta la lista separada
alzheimer
# Out:
#     Group;Sexo;Age;Educ;SES;MMSE;CDR;eTIV;nWBV;ASF
# 0          Control;F;87;14;2;27;0;1987;0.696;0.883
# 1          Control;F;88;14;2;30;0;2004;0.681;0.876
# 2            DCL;F;75;12;3;23;0.5;1678;0.736;1.046
# 3             DCL;F;76;12;2;28;0.5;1738;0.713;1.01
# 4            DCL;F;80;12;3;22;0.5;1698;0.701;1.034
# ..                                             ...
# 368          DCL;F;82;16;1;28;0.5;1693;0.694;1.037
# 369           DCL;F;86;16;1;26;0.5;1688;0.675;1.04
# 370        Control;M;61;13;2;30;0;1319;0.801;1.331
# 371        Control;M;63;13;2;30;0;1327;0.796;1.323
# 372        Control;M;65;13;2;30;0;1333;0.801;1.317
#
# [373 rows x 1 columns]

# %%
alzheimer = pd.read_csv(file[0], sep=";" )
#hacemos primero lo de file[o], e imprimimos para mirar como estan organizadas las listas
# luego vemos que estan separadas por ; entonces ponemos el sep

# %%
alzheimer #Ver lo que imprime
# Out:
#        Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Control    F   87    14    2    27  0.0  1987  0.696  0.883
# 1    Control    F   88    14    2    30  0.0  2004  0.681  0.876
# 2        DCL    F   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL    F   76    12    2    28  0.5  1738  0.713  1.010
# 4        DCL    F   80    12    3    22  0.5  1698  0.701  1.034
# ..       ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      DCL    F   82    16    1    28  0.5  1693  0.694  1.037
# 369      DCL    F   86    16    1    26  0.5  1688  0.675  1.040
# 370  Control    M   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control    M   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control    M   65    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
alzheimer.size
# Out:
# 3730

# %%
alzheimer.shape
# Out:
# (373, 10)

# %%
# Como accdeder a los indices de las columnas

alzheimer.columns
# Out:
# Index(['Group', 'Sexo', 'Age', 'Educ', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV',
#        'ASF'],
#       dtype='object')

# %%
#Como accedo a una sola columna
alzheimer['Sexo']
# Out:
# 0      F
# 1      F
# 2      F
# 3      F
# 4      F
#       ..
# 368    F
# 369    F
# 370    M
# 371    M
# 372    M
# Name: Sexo, Length: 373, dtype: object

# %%
alzheimer['Sexo'].describe() #Muestra la info de esa columna, tambein se puede transponer, y todo
# Out:
# count     373
# unique      2
# top         M
# freq      213
# Name: Sexo, dtype: object

# %%
alzheimer.loc[1] # Para buscar por el indice,--> Por fila , TIPO POR PACIENTE
# Out:
# Group    Control
# Sexo           F
# Age           88
# Educ          14
# SES            2
# MMSE          30
# CDR          0.0
# eTIV        2004
# nWBV       0.681
# ASF        0.876
# Name: 1, dtype: object

# %%
alzheimer_copy = alzheimer.copy() #es igual a la original ,pero para guardar en otra variable
alzheimer_copy
# Out:
#        Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Control    F   87    14    2    27  0.0  1987  0.696  0.883
# 1    Control    F   88    14    2    30  0.0  2004  0.681  0.876
# 2        DCL    F   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL    F   76    12    2    28  0.5  1738  0.713  1.010
# 4        DCL    F   80    12    3    22  0.5  1698  0.701  1.034
# ..       ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      DCL    F   82    16    1    28  0.5  1693  0.694  1.037
# 369      DCL    F   86    16    1    26  0.5  1688  0.675  1.040
# 370  Control    M   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control    M   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control    M   65    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
#Resetear los indices que tenemos . 
alzheimer_copy = alzheimer.copy().reset_index() 
alzheimer_copy
# Out:
#      index    Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0        0  Control    F   87    14    2    27  0.0  1987  0.696  0.883
# 1        1  Control    F   88    14    2    30  0.0  2004  0.681  0.876
# 2        2      DCL    F   75    12    3    23  0.5  1678  0.736  1.046
# 3        3      DCL    F   76    12    2    28  0.5  1738  0.713  1.010
# 4        4      DCL    F   80    12    3    22  0.5  1698  0.701  1.034
# ..     ...      ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368    368      DCL    F   82    16    1    28  0.5  1693  0.694  1.037
# 369    369      DCL    F   86    16    1    26  0.5  1688  0.675  1.040
# 370    370  Control    M   61    13    2    30  0.0  1319  0.801  1.331
# 371    371  Control    M   63    13    2    30  0.0  1327  0.796  1.323
# 372    372  Control    M   65    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 11 columns]

# %%
#Como borro una columna
alzheimer_copy = alzheimer_copy.drop(['index'],axis=1) #Estamos borrando la columna index que es la 1, tambien se puede poner por numero [4],axis=4
alzheimer_copy
# Out:
#        Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Control    F   87    14    2    27  0.0  1987  0.696  0.883
# 1    Control    F   88    14    2    30  0.0  2004  0.681  0.876
# 2        DCL    F   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL    F   76    12    2    28  0.5  1738  0.713  1.010
# 4        DCL    F   80    12    3    22  0.5  1698  0.701  1.034
# ..       ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      DCL    F   82    16    1    28  0.5  1693  0.694  1.037
# 369      DCL    F   86    16    1    26  0.5  1688  0.675  1.040
# 370  Control    M   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control    M   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control    M   65    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
alzheimer_copy = alzheimer_copy.drop(['Sexo'],axis=1) #Estamos borrando la columna index que es la 1, tambien se puede poner por numero [4],axis=4
alzheimer_copy
# Out:
#        Group  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Control   87    14    2    27  0.0  1987  0.696  0.883
# 1    Control   88    14    2    30  0.0  2004  0.681  0.876
# 2        DCL   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL   76    12    2    28  0.5  1738  0.713  1.010
# 4        DCL   80    12    3    22  0.5  1698  0.701  1.034
# ..       ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      DCL   82    16    1    28  0.5  1693  0.694  1.037
# 369      DCL   86    16    1    26  0.5  1688  0.675  1.040
# 370  Control   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control   65    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 9 columns]

# %%
alzheimer_copy = alzheimer_copy.drop([4],axis=0) #Quitamos la 4
alzheimer_copy
# Out:
#        Group  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Control   87    14    2    27  0.0  1987  0.696  0.883
# 1    Control   88    14    2    30  0.0  2004  0.681  0.876
# 2        DCL   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL   76    12    2    28  0.5  1738  0.713  1.010
# 5    Control   88    18    3    28  0.0  1815  0.710  1.444
# ..       ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      DCL   82    16    1    28  0.5  1693  0.694  1.037
# 369      DCL   86    16    1    26  0.5  1688  0.675  1.040
# 370  Control   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control   65    13    2    30  0.0  1333  0.801  1.317
#
# [372 rows x 9 columns]

# %%
#Otra forma de borrar
del alzheimer_copy

# %%
#Asignar un indice adicional
alzheimer_copy=alzheimer_copy.assign(falseIndex=np.random.rand(372)) #372 SEMILLA
alzheimer_copy
# Out:
#        Group  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  falseIndex
# 0    Control   87    14    2    27  0.0  1987  0.696  0.883    0.038681
# 1    Control   88    14    2    30  0.0  2004  0.681  0.876    0.807034
# 2        DCL   75    12    3    23  0.5  1678  0.736  1.046    0.785282
# 3        DCL   76    12    2    28  0.5  1738  0.713  1.010    0.995636
# 5    Control   88    18    3    28  0.0  1815  0.710  1.444    0.502780
# ..       ...  ...   ...  ...   ...  ...   ...    ...    ...         ...
# 368      DCL   82    16    1    28  0.5  1693  0.694  1.037    0.189565
# 369      DCL   86    16    1    26  0.5  1688  0.675  1.040    0.242883
# 370  Control   61    13    2    30  0.0  1319  0.801  1.331    0.757648
# 371  Control   63    13    2    30  0.0  1327  0.796  1.323    0.765927
# 372  Control   65    13    2    30  0.0  1333  0.801  1.317    0.340436
#
# [372 rows x 10 columns]

# %%
mmse = pd.read_csv(file[1], sep=";" )
mmse
# Out:
#      Codigo  Edad en la visita       Sexo  Escolaridad  Orientacion y Tiempo  \
# 0   CTR_001                 56   Femenino            6                     5
# 1   CTR_002                 53   Femenino            3                     5
# 2   CTR_003                 56  Masculino           16                     5
# 3   CTR_004                 47   Femenino           11                     5
# 4   CTR_005                 60   Femenino            5                     4
# 5   CTR_006                 63  Masculino            5                     5
# 6   CTR_007                 48   Femenino           11                     5
# 7   CTR_008                 55  Masculino           14                     5
# 8   CTR_009                 39   Femenino           16                     5
# 9   CTR_010                 49  Masculino           13                     5
# 10  CTR_011                 56  Masculino            6                     5
# ...

# %%
mmse.shape
# Out:
# (23, 11)

# %%
mmse.columns
# Out:
# Index(['Codigo', 'Edad en la visita', 'Sexo', 'Escolaridad',
#        'Orientacion y Tiempo', 'Orientacion y Lugar', 'Memoria de fijacion',
#        'Atencion', 'Memoria de Evocacion', 'Lenguaje', 'Total'],
#       dtype='object')

# %%
mmse.size
# Out:
# 253

# %%
#Hacer filtro 

alzheimer_edad_70 = alzheimer[(alzheimer['Age'] >= 90)] # Este es el filtro que le estamos aplicando a la serie alzheminer
# Le vamos a mirar que los datos que estan en la columna Age tenga un valor mayor o iguAL A 70
print(alzheimer_edad_70)
print(alzheimer_copy)
# Out:
#        Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 6    Control    M   90    18    3    27  0.0  1600  0.718  1.462
# 13   Control    M   93    14    2    30  0.0  1272  0.698  1.380
# 14   Control    M   95    14    2    29  0.0  1257  0.703  1.396
# 28       DCL    F   90     8    4    23  0.5  1668  0.646  1.052
# 35       DTA    M   92    14    1    27  0.5  1423  0.696  1.234
# 59       DTA    M   91    12    3    28  0.5  1463  0.696  1.199
# 60       DCL    F   90    12    3    21  0.5  1307  0.679  1.342
# 61       DCL    F   92    12    3    24  0.5  1311  0.676  1.339
# 107  Control    M   92    23    1    29  0.0  1454  0.701  1.207
# 108  Control    M   94    23    1    29  0.0  1474  0.696  1.190
# 109  Control    M   97    23    1    30  0.0  1483  0.689  1.184
# 146  Control    M   90    12    3    29  0.0  1475  0.676  1.190
# 169  Control    F   91    16    1    28  0.0  1640  0.670  1.070
# ...

# %%
alzheimer_edad_70.shape
# Out:
# (21, 10)

# %%
alzheimer_educ = alzheimer[(alzheimer['Educ'] < 14)] # Cual es la columna de interes, la podemos cambiar

#               este alzherimer  =  se puede cambiar y elegir el database de interners, si ya hemos filtrado
# El que esta antes del []
print(alzheimer_educ)
print(alzheimer_educ.shape)
# Out:
#        Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 2        DCL    F   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL    F   76    12    2    28  0.5  1738  0.713  1.010
# 4        DCL    F   80    12    3    22  0.5  1698  0.701  1.034
# 7    Control    F   80    12    4    28  0.0  1689  0.712  1.039
# 8    Control    F   83    12    4    29  0.5  1701  0.711  1.032
# ..       ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 363  Control    M   68    13    2    30  0.0  1506  0.740  1.165
# 364  Control    M   72    13    2    30  0.0  1510  0.723  1.162
# 370  Control    M   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control    M   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control    M   65    13    2    30  0.0  1333  0.801  1.317
#
# [153 rows x 10 columns]
# (153, 10)

# %%
#Operacions de columnas

alzheimer.max()
# Out:
# Group      DTA
# Sexo         M
# Age         98
# Educ        23
# SES          5
# MMSE        30
# CDR        2.0
# eTIV      2004
# nWBV     0.837
# ASF      1.587
# dtype: object

# %%
alzheimer['Educ'].mean()
# Out:
# 14.597855227882038

# %% [markdown]
# ## SEABORN
#
# **Otra forma de graficar con pandas**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x= 'Educ',y='Age',data = alzheimer, estimator=np.median)
plt.title("Promedio de las cosas")
# Out:
# Text(0.5, 1.0, 'Promedio de las cosas')

# %%
sns.histplot(x= 'Educ',y='Age',data = alzheimer)
# Out:
# <Axes: xlabel='Educ', ylabel='Age'>
