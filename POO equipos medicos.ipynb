# %%
class EquipoMedico:
    def __init__(self, nombre, marca, estado_funcionamiento):
        self.nombre = nombre
        self.marca = marca
        self.estado_funcionamiento = estado_funcionamiento

    def __str__(self):
        return f"Nombre: {self.nombre}, Marca: {self.marca}, Estado de funcionamiento: {self.estado_funcionamiento}"


class ResonanciaMagnetica(EquipoMedico):
    def __init__(self, nombre, marca, estado_funcionamiento, parametros_imagen):
        super().__init__(nombre, marca, estado_funcionamiento)
        self.parametros_imagen = parametros_imagen

    def configurar_parametros_imagen(self, nuevos_parametros):
        self.parametros_imagen = nuevos_parametros

    def __str__(self):
        return super().__str__() + f", Parámetros de imagen: {self.parametros_imagen}"


class Electrocardiograma(EquipoMedico):
    def __init__(self, nombre, marca, estado_funcionamiento):
        super().__init__(nombre, marca, estado_funcionamiento)

    def analizar_actividad_cardiaca(self, datos):
        # Aquí iría la lógica para analizar la actividad cardiaca y generar reportes
        pass


# Ejemplo de uso
resonancia = ResonanciaMagnetica("Resonancia 1", "Marca A", "Funcionando", parametros_imagen="Default")
print(resonancia)
resonancia.configurar_parametros_imagen("Nuevos parámetros")
print(resonancia)

ecg = Electrocardiograma("ECG 1", "Marca B", "Funcionando")
print(ecg)
ecg.analizar_actividad_cardiaca(datos="Datos del paciente")

# %%
class EquipoMedico:
    def __init__(self, nombre, marca, estado_funcionamiento):
        self.nombre = nombre
        self.marca = marca
        self.estado_funcionamiento = estado_funcionamiento

    def __str__(self):
        return f"Nombre: {self.nombre}, Marca: {self.marca}, Estado de funcionamiento: {self.estado_funcionamiento}"


class ResonanciaMagnetica(EquipoMedico):
    def __init__(self, nombre, marca, estado_funcionamiento, parametros_imagen):
        super().__init__(nombre, marca, estado_funcionamiento)
        self.parametros_imagen = parametros_imagen

    def configurar_parametros_imagen(self, nuevos_parametros):
        self.parametros_imagen = nuevos_parametros

    def __str__(self):
        return super().__str__() + f", Parámetros de imagen: {self.parametros_imagen}"


class Electrocardiograma(EquipoMedico):
    def __init__(self, nombre, marca, estado_funcionamiento):
        super().__init__(nombre, marca, estado_funcionamiento)

    def analizar_actividad_cardiaca(self, datos):
        # Aquí iría la lógica para analizar la actividad cardiaca y generar reportes
        pass


# Bucle principal
equipos = []
while True:
    print("\nMenú:")
    print("1. Crear Resonancia Magnética")
    print("2. Crear Electrocardiograma")
    print("3. Mostrar Equipos")
    print("4. Salir")

    opcion = input("Seleccione una opción: ")

    if opcion == "1":
        nombre = input("Ingrese el nombre de la resonancia magnética: ")
        marca = input("Ingrese la marca de la resonancia magnética: ")
        estado = input("Ingrese el estado de funcionamiento de la resonancia magnética: ")
        parametros = input("Ingrese los parámetros de imagen de la resonancia magnética: ")
        resonancia = ResonanciaMagnetica(nombre, marca, estado, parametros)
        equipos.append(resonancia)
        print("Resonancia Magnética creada exitosamente.")
    elif opcion == "2":
        nombre = input("Ingrese el nombre del electrocardiograma: ")
        marca = input("Ingrese la marca del electrocardiograma: ")
        estado = input("Ingrese el estado de funcionamiento del electrocardiograma: ")
        ecg = Electrocardiograma(nombre, marca, estado)
        equipos.append(ecg)
        print("Electrocardiograma creado exitosamente.")
    elif opcion == "3":
        print("\nEquipos Médicos:")
        for equipo in equipos:
            print(equipo)
    elif opcion == "4":
        print("Saliendo del programa...")
        break
    else:
        print("Opción inválida. Por favor, seleccione una opción válida.")
